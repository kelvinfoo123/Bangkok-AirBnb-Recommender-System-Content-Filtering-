# %%
import pandas as pd 
import numpy as np 
import ast

# %%
df = pd.read_csv('/Users/kelvinfoo/Desktop/AI Masters/AirBnb Project/Data/listing_with_cluster.csv')

# Convert amenities and neighbourhood to lower case 
df['amenities'] = df['amenities'].apply(ast.literal_eval)
df['amenities'] = df['amenities'].apply(lambda x: [item.lower() for item in x])
df['neighbourhood_cleansed'] = df['neighbourhood_cleansed'].str.lower()

# Convert Boolean attribute to True and False 
df['host_is_superhost'] = df['host_is_superhost'].map({'t': True, 'f': False})
df['host_identity_verified'] = df['host_identity_verified'].map({'t': True, 'f': False})

df['embedding'] = df['embedding'].apply(lambda x: np.array([float(i) for i in x.strip("[]").split()]) if isinstance(x, str) else x)
print(f"Data shape: {df.shape}")
df.head()
# Out:
# Data shape: (24977, 17)
#    Unnamed: 0.1  Unnamed: 0                                          name  \
# 0             3           3  Comfy bedroom near River pier & BTS  Taksin.
# 1             4           4           Central Bangkok 3 Bedroom Apartment
# 2            10          10                 Oasis in the heart of Bangkok
# 3            12          12    Monthly rent 2Beds/2Baths quiet APT at BTS
# 4            13          13               Nice room with superb city view
#
#                                          description  \
# 0  This is one of our 'Escape' sleep room : hoste...
# 1  We are Airbnb Super Hosts. Book our apartment ...
# 2  In the mid of vibrant in the center of Bangkok...
# 3  This is a monthly rented apartment. Our clean ...
# 4  Our cool and comfortable one bedroom apartment...
#
#                                neighborhood_overview  host_is_superhost  \
# 0  Charoen krung street, River pier, Iconsiam, Su...               True
# 1  Sukhumvit Rd is the shopping and restaurant di...              False
# 2  Local small food market during the day close t...              False
# 3  Taksin is a very local residential neighborhoo...               True
# 4  It is very center of Bangkok and easy access t...              False
#
#    host_identity_verified neighbourhood_cleansed        room_type  \
# 0                    True                 sathon       Hotel room
# 1                    True            khlong toei  Entire home/apt
# 2                    True            ratchathewi  Entire home/apt
# 3                    True             khlong san  Entire home/apt
# 4                    True            ratchathewi  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  \
# 0             2          1         1
# 1             5          3         3
# 2             2          1         1
# 3             4          2         2
# 4             2          1         1
#
#                                            amenities  price  \
# 0  [shampoo, hangers, breakfast, hot water, tv wi...   1536
# 1  [shampoo, tv with standard cable, extra pillow...   5601
# 2  [shampoo, freezer, kitchen, shared pool, dedic...   1366
# 3  [shampoo, hangers, kitchen, free parking on pr...   1810
# 4  [shampoo, kitchen, hangers, elevator, smoke al...   1878
#
#    review_scores_value                                          embedding  \
# 0                 4.69  [0.060480874, 0.0582088716, 0.0019648266, 0.05...
# 1                 4.76  [0.0409337059, -0.0361530222, 0.0519887842, 0....
# 2                 4.86  [0.0329679251, 0.0403496213, -0.0546748601, 0....
# 3                 4.71  [-0.0121601848, 0.019530328, -0.015967356, 0.0...
# 4                 4.75  [0.111119725, -0.0271609426, 0.037512105, 0.00...
#
#    agg_cluster
# 0            2
# 1            0
# 2            0
# 3            0
# 4            2

# %% [markdown]
# ### **Building Recommender System**

# %%
def get_user_preference(): 
    try: 
        def positive_int_input(prompt): 
            while True: 
                value = input(prompt)
                if not value: 
                    print("This field is required. Please enter a number greater than or equal to 1.")
                else: 
                    try: 
                        value = int(value)
                        if value >= 1: 
                            return value 
                        else: 
                            print("Please enter a number greater than or equal to 1.")
                    except ValueError: 
                        print("Invalid input. Please enter a valid number greater than or equal to 1.")

        def greater_than_zero_input(prompt): 
            while True: 
                value = input(prompt)
                if not value: 
                    print("This field is required. Please enter a number greater than or equal to 0.")
                else: 
                    try: 
                        value = int(value) 
                        if value > 0: 
                            return value 
                        else: 
                            print("Please enter a number greater than or equal to 0.")
                    except ValueError: 
                        print("Invalid input. Please enter a valid number greater than or equal to 0.")
        
        accommodates = positive_int_input("Minimum number of guest(s) (must be 1 or more): ")
        price = greater_than_zero_input("Maximum price: ")
        bathrooms = greater_than_zero_input("Minimum number of bathroom(s): ")
        bedrooms = greater_than_zero_input("Minimum number of bedroom(s): ")

        verifiedHost = input("Only verified host (Y/N): ").strip().upper()
        if verifiedHost == "YES":
            verifiedHost = "Y"
        elif verifiedHost == "NO":
            verifiedHost = "N"
        verifiedHost = True if verifiedHost == "Y" else False if verifiedHost == "N" else None
        superHost = input("Only super host (Y/N): ").strip().upper()
        if superHost == "YES":
            superHost = "Y"
        elif superHost == "NO":
            superHost = "N"
        superHost = True if superHost == "Y" else False if superHost == "N" else None
        amenities = input("Preferred amenities, seperated by commas: ")
        amenities = [a.strip() for a in amenities.strip(",")] if amenities else None

        listing_name = input("I would prefer similar listings as: ")
        listing_name = listing_name if listing_name else None 

        userPreferences = {"accommodates": accommodates,
                       "price": price,
                       "bathrooms": bathrooms,
                       "bedrooms": bedrooms,
                       "verified_host": verifiedHost,
                       "super_host": superHost,
                       "amenities": amenities, 
                       "listing_name": listing_name}
        return userPreferences
    
    except ValueError: 
        print("Unexpected input error. Please try again.")
        return get_user_preference()

# %%
def filter_listing(userPreferences):
    preferred_listing_cluster = df[df['name'] == userPreferences['listing_name']]['agg_cluster'].iloc[0] if userPreferences['listing_name'] is not None else True
    cluster_filter = df['agg_cluster'] == preferred_listing_cluster 

    accommodatesFilter = df['accommodates'] == userPreferences['accommodates'] if userPreferences['accommodates'] is not None else True
    priceFilter = df['price'] <= userPreferences['price'] if userPreferences['price'] is not None else True
    bathroomsFilter = df['bathrooms'] >= userPreferences['bathrooms'] if userPreferences['bathrooms'] is not None else True
    bedroomsFilter = df['bedrooms'] >= userPreferences['bedrooms'] if userPreferences['bedrooms'] is not None else True
    
    verified_hostFilter = (df['host_identity_verified'] == True) if userPreferences['verified_host'] == True else True
    super_hostFilter = (df['host_is_superhost'] == True) if userPreferences['super_host'] == True else True

    tailoredListings = df[accommodatesFilter &
                          priceFilter &
                          bathroomsFilter &
                          bedroomsFilter &
                          verified_hostFilter &
                          super_hostFilter & 
                          cluster_filter]

    if userPreferences['amenities']: 
        tailoredListings = tailoredListings[tailoredListings['amenities'].apply(lambda am: any(any(keyword in amen for amen in am) for keyword in userPreferences['amenities']))]
    return tailoredListings

# %%
def main(): 
    userPreferences = get_user_preference()
    user_filteredListings = filter_listing(userPreferences)

    final_recommendation = user_filteredListings.iloc[:, 2:14]
    final_recommendation = final_recommendation.rename(columns = {'host_is_superhost': 'superhost', 'host_identity_verified': 'verified_host', 'neighborhood_cleansed': 'neighborhood', 'review_scores_value': 'review_score'})
    return final_recommendation

if __name__ == "__main__": 
    print("Here are your recommendations: ")
    final_recommendation = main()
    display(final_recommendation)
# Out:
# Here are your recommendations:
#                                                     name  \
# 201                     S1 hostel (Dorm) Sathorn Bangkok
# 357                      505 Cozy studio, BTS Phromphong
# 631                         Corner Room+ Pool+ Sky train
# 758    Stylish Single room near Tong lo Station Sukhu...
# 784                     Warmy @ 600m MRT Bangson Station
# ...                                                  ...
# 24585              Lower Bed in Female Only dorm 10 Beds
# 24597              Upper Bed in Female Only dorm 10 Beds
# 24598               Lower bed in Female Only dorm 4 Beds
# 24599               Upper bed in Female Only dorm 4 Beds
# 24973  Cozy Single Bed Room with A/C &  Private Bathroom
#
#                                              description  \
# 201    Stylish budget hostel in the midst of Bangkok,...
# 357    Welcome to our home, centrally-located townhou...
# 631    The link 2, 5 minutes walk to Onnuch BTS Skytr...
# 758    We offer the trendiest room in the heart of ci...
# 784    -600m to MRT Bangson Station by walk<br />-10k...
# ...                                                  ...
# 24585  Located within less than 1 km of Bangkok Natio...
# 24597  Located within less than 1 km of Bangkok Natio...
# 24598  Located within less than 1 km of Bangkok Natio...
# 24599  Located within less than 1 km of Bangkok Natio...
# 24973  Welcome to your perfect city retreat! This bea...
#
#                                    neighborhood_overview  superhost  \
# 201    Our hostel is located on small greenery road. ...       True
# 357                                                  NaN       True
# 631                                                  NaN      False
# 758    Thong Lo area is the upper scale residential a...      False
# 784    My place location is not the ideal location fo...       True
# ...                                                  ...        ...
# 24585                                                NaN      False
# 24597                                                NaN      False
# 24598                                                NaN      False
# 24599                                                NaN      False
# 24973                                                NaN       True
#
#        verified_host neighbourhood_cleansed        room_type  accommodates  \
# 201             True                 sathon      Shared room             1
# 357             True                vadhana     Private room             1
# 631             True                vadhana     Private room             1
# 758             True                vadhana     Private room             1
# 784             True               bang sue  Entire home/apt             1
# ...              ...                    ...              ...           ...
# 24585           True            phra nakhon      Shared room             1
# 24597           True            phra nakhon      Shared room             1
# 24598           True            phra nakhon      Shared room             1
# 24599           True            phra nakhon      Shared room             1
# 24973           True              bang kapi     Private room             1
#
#        bathrooms  bedrooms                                          amenities  \
# 201            1         1  [shampoo, body soap, extra pillows and blanket...
# 357            1         1  [shampoo, iron, piano, shower gel, wifi, clean...
# 631            1         1  [shared pool, dedicated workspace, elevator, a...
# 758            1         1   [tv with standard cable, wifi, air conditioning]
# 784            1         1  [city skyline view, shampoo, iron, hot water k...
# ...          ...       ...                                                ...
# 24585          2         1                           [air conditioning, wifi]
# 24597          2         1                           [air conditioning, wifi]
# 24598          2         1                           [air conditioning, wifi]
# 24599          2         1                           [air conditioning, wifi]
# 24973          1         1  [shampoo, iron, hot water kettle, ceiling fan,...
#
#        price
# 201      380
# 357      937
# 631      351
# 758      570
# 784      850
# ...      ...
# 24585    696
# 24597    616
# 24598    696
# 24599    616
# 24973    520
#
# [96 rows x 12 columns]
